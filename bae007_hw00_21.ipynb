# %% [markdown]
# # Знакомство с SymPy

# %% [markdown]
# ### Индивидуальное домашнее задание

# %% [markdown]
# ### Барановская Анастасия Евгеньевна (bae007), группа: Б21-515

# %% [markdown]
# **Выполните указанные ниже действия, сохраните свою работу в виде ipynb-файла с именем `bae007_hw00_21.ipynb` и прикрепите этот файл к сообщению своему преподавателю**.

# %% [markdown]
# **Задание 1.** Вычислите значение выражения $\displaystyle\log_2\left(\frac{\sqrt[3]{e}}{(\pi-e){(\cos3+5)}^2}+\sqrt[4]{\pi^3}\right)$ с точностью 30 значащих десятичных цифр.

# %%
from sympy import *
t=log(E**(S(1)/3)/(((pi-E)*(cos(3)+5))**(S(2)))+(pi)**(S(3)/4))/log(2)
print(N(t, 30))
# Out:
# 1.50796026165086550134206121668

# %% [markdown]
# **Задание 2.** Раскройте скобки в выражении $\left(x - 2 y\right) \left(x - y\right)^{3} \left(2 u + z - 1\right)^{3}$.

# %%
from sympy import *
var('x y u z')
t=(x-2*y)*(x-y)**3*(2*u+z-1)**3
expand(t)
# Out:
# 8*u**3*x**4 - 40*u**3*x**3*y + 72*u**3*x**2*y**2 - 56*u**3*x*y**3 + 16*u**3*y**4 + 12*u**2*x**4*z - 12*u**2*x**4 - 60*u**2*x**3*y*z + 60*u**2*x**3*y + 108*u**2*x**2*y**2*z - 108*u**2*x**2*y**2 - 84*u**2*x*y**3*z + 84*u**2*x*y**3 + 24*u**2*y**4*z - 24*u**2*y**4 + 6*u*x**4*z**2 - 12*u*x**4*z + 6*u*x**4 - 30*u*x**3*y*z**2 + 60*u*x**3*y*z - 30*u*x**3*y + 54*u*x**2*y**2*z**2 - 108*u*x**2*y**2*z + 54*u*x**2*y**2 - 42*u*x*y**3*z**2 + 84*u*x*y**3*z - 42*u*x*y**3 + 12*u*y**4*z**2 - 24*u*y**4*z + 12*u*y**4 + x**4*z**3 - 3*x**4*z**2 + 3*x**4*z - x**4 - 5*x**3*y*z**3 + 15*x**3*y*z**2 - 15*x**3*y*z + 5*x**3*y + 9*x**2*y**2*z**3 - 27*x**2*y**2*z**2 + 27*x**2*y**2*z - 9*x**2*y**2 - 7*x*y**3*z**3 + 21*x*y**3*z**2 - 21*x*y**3*z + 7*x*y**3 + 2*y**4*z**3 - 6*y**4*z**2 + 6*y**4*z - 2*y**4

# %% [markdown]
# **Задание 3.** Разложите на множители многочлен $4 u^{4} x + 8 u^{4} y - 8 u^{3} x^{2} - 28 u^{3} x y - 24 u^{3} y^{2} + 4 u^{2} x^{3} + 24 u^{2} x^{2} y + 45 u^{2} x y^{2} + 26 u^{2} y^{3} - 4 u x^{3} y - 18 u x^{2} y^{2} - 26 u x y^{3} - 12 u y^{4} + x^{3} y^{2} + 4 x^{2} y^{3} + 5 x y^{4} + 2 y^{5}$.

# %%
from sympy import *
var('u x y')
t=4*u**4*x+8*u**4*y-8*u**3*x**2-28*u**3*x*y-24*u**3*y**2+4*u**2*x**3+24*u**2*x**2*y+45*u**2*x*y**2+26*u**2*y**3-4*u*x**3*y-18*u*x**2*y**2-26*u*x*y**3-12*u*y**4+x**3*y**2+4*x**2*y**3+5*x*y**4+2*y**5
factor(t)
# Out:
# (-2*u + y)**2*(x + 2*y)*(-u + x + y)**2

# %% [markdown]
# **Задание 4.** Найдите все (включая комплексные) корни уравнения $12 x^{4} + 13 x^{3} + 68 x^{2} + 78 x - 24 = 0$.

# %%
from sympy import *
var('x')
solveset(12*x**4+13*x**3+68*x**2+78*x-24,x)
# Out:
# FiniteSet(-4/3, 1/4, sqrt(6)*I, -sqrt(6)*I)

# %% [markdown]
# **Задание 5.** Постройте график функции, заданной неявно: $\displaystyle - x^{2} - x y^{2} + 2 y^{3}=0$. Используйте одинаковый масштаб по координатным осям.

# %%
from sympy import *
var('x y')
plot_implicit(-x**2-x*y**2+2*y**3, aspect_ratio = (1,1))

# %% [markdown]
# **Задание 6.** Постройте график функции, заданной параметрически: $\displaystyle x(t)=5 \sin{\left(7 t \right)}$, $\displaystyle y(t)=4 \sin{\left(6 t \right)}$. Используйте минимальный по длине промежуток изменения параметра и одинаковый масштаб по координатным осям.

# %%
from sympy import *
var('t')
plotting.plot_parametric(5*sin(7*t), 4*sin(6*t), (t, 0, 2*pi), aspect_ratio = (1,1))
